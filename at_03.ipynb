# %%
import time, copy, pathlib, torch
from torch import nn, optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

# %%
import pandas as pd
from pathlib import Path
from PIL import Image

import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from sklearn.model_selection import train_test_split

# ---------- Custom Dataset ----------
class RetinopathyDataset(Dataset):
    """
    Loads <id_code>.png images and integer labels from a CSV file.

    Args
    ----
    df : pandas.DataFrame
        Must contain 'id_code' and 'diagnosis' columns.
    img_dir : str or Path
        Directory where *.png images live.
    transform : callable, optional
        TorchVision transform pipeline applied to each PIL image.
    """
    def __init__(self, df: pd.DataFrame, img_dir: str, transform=None):
        self.df = df.reset_index(drop=True)
        self.img_dir = Path(img_dir)
        self.transform = transform

    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(self, idx: int):
        row   = self.df.iloc[idx]
        img_f = self.img_dir / f"{row.id_code}.png"
        img   = Image.open(img_f).convert("RGB")     # ensure 3-channel

        if self.transform is not None:
            img = self.transform(img)

        label = torch.tensor(row.diagnosis, dtype=torch.long)
        return img, label


# ---------- Convenience factory ----------
def make_dataloaders(csv_path: str,
                     img_dir: str,
                     batch_size: int = 32,
                     val_frac: float = 0.2,
                     seed: int = 42,
                     num_workers: int = 4):
    """
    Reads the CSV, splits it into train / val (stratified), builds DataLoaders.
    Returns
    -------
    train_dl, val_dl  (torch.utils.data.DataLoader)
    """

    df = pd.read_csv(csv_path)

    train_df, val_df = train_test_split(
        df,
        test_size   = val_frac,
        stratify    = df["diagnosis"],
        random_state= seed,
    )

    # --- Transforms (EfficientNet default size) ---
    train_tfms = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.AutoAugment(transforms.AutoAugmentPolicy.IMAGENET),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std =(0.229, 0.224, 0.225)),
    ])

    val_tfms = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std =(0.229, 0.224, 0.225)),
    ])

    train_ds = RetinopathyDataset(train_df, img_dir, transform=train_tfms)
    val_ds   = RetinopathyDataset(val_df,   img_dir, transform=val_tfms)

    train_dl = DataLoader(train_ds, batch_size=batch_size,
                          shuffle=True, drop_last=False,
                          num_workers=num_workers, pin_memory=True)

    val_dl   = DataLoader(val_ds,   batch_size=batch_size,
                          shuffle=False, drop_last=False,
                          num_workers=num_workers, pin_memory=True)

    return train_dl, val_dl

# %%
# train_dl, val_dl = make_dataloaders("data/aptos2019-blindness-detection/train.csv", "data/aptos2019-blindness-detection/train_images" )

# %%
CSV_PATH = "data/aptos2019-blindness-detection/train.csv"   # your CSV
IMG_DIR  = "data/aptos2019-blindness-detection/train_images"             # where the *.png files live

train_loader, val_loader = make_dataloaders(
    CSV_PATH,
    IMG_DIR,
    batch_size = 32,
    val_frac   = 0.15,   # 85 % train, 15 % val
)

# Iterate once
for imgs, labels in train_loader:
    print(imgs.shape, labels.shape)   # -> torch.Size([32, 3, 224, 224]) torch.Size([32])
    break
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32])

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLASSES    = 5

# %%
# !pip install -U transformers datasets timm evaluate scikit-learn pillow torchvision
# Out:
# Requirement already satisfied: transformers in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (4.54.1)
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting timm
#   Downloading timm-1.0.19-py3-none-any.whl.metadata (60 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: scikit-learn in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: pillow in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (11.3.0)
# Requirement already satisfied: torchvision in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (0.20.1)
# Collecting torchvision
#   Downloading torchvision-0.22.1-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: requests in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.7.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from datasets) (2.3.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py39-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.12.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: torch in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from timm) (2.5.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Collecting torch (from timm)
#   Using cached torch-2.7.1-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: sympy>=1.13.3 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from torch->timm) (1.13.3)
# Requirement already satisfied: networkx in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from torch->timm) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch->timm)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch->timm)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch->timm)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->timm)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch->timm)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch->timm)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch->timm)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch->timm)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch->timm)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->timm)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->timm)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch->timm)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch->timm)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch->timm)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch->timm)
#   Using cached triton-3.3.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from triton==3.3.1->torch->timm) (78.1.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.7.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading multidict-6.6.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading propcache-0.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading yarl-1.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
# Downloading timm-1.0.19-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 527.0 kB/s eta 0:00:001m520.9 kB/s eta 0:00:01
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
# Downloading torchvision-0.22.1-cp39-cp39-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 1.4 MB/s eta 0:00:001.4 MB/s eta 0:00:010m
# Downloading torch-2.7.1-cp39-cp39-manylinux_2_28_x86_64.whl (821.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.1/821.1 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:12
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:04
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 793.8 kB/s eta 0:00:00MB/s eta 0:00:01
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 3.2 MB/s eta 0:00:00m eta 0:00:010:00:04
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:02
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.6 MB/s eta 0:00:006.2 MB/s eta 0:00:01
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 4.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 5.0 MB/s eta 0:00:00m eta 0:00:010:00:02
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 5.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:00:02
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached aiohttp-3.12.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached multidict-6.6.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (239 kB)
# Using cached yarl-1.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (327 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
# Using cached propcache-0.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (200 kB)
# Using cached pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (42.7 MB)
# Using cached xxhash-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (193 kB)
# WARNING: Error parsing dependencies of fsspec: [Errno 2] No such file or directory: '/home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages/fsspec-2025.7.0.dist-info/METADATA'
# Installing collected packages: nvidia-cusparselt-cu12, xxhash, triton, pyarrow, propcache, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, multidict, fsspec, frozenlist, dill, attrs, async-timeout, aiohappyeyeballs, yarl, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, aiosignal, nvidia-cusolver-cu12, aiohttp, torch, torchvision, datasets, timm, evaluate
#   Attempting uninstall: triton━━━━━━━━━━━━━━━━━━━━━━━━  0/34 [nvidia-cusparselt-cu12]
#     Found existing installation: triton 3.1.0━━━━━  0/34 [nvidia-cusparselt-cu12]
#     Uninstalling triton-3.1.0:━━━━━━━━━━━━━━━━━━━━  0/34 [nvidia-cusparselt-cu12]
#       Successfully uninstalled triton-3.1.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/34 [triton]
#   Attempting uninstall: fsspec━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 14/34 [multidict]las-cu12]u12]c-cu12]2]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 14/34 [multidict]    WARNING: No metadata found in /home/suchiralaknath/anaconda3/envs/deep-ensemble/lib/python3.9/site-packages
#     Found existing installation: fsspec 2025.7.0
#     Can't uninstall 'fsspec'. No files were found to uninstall.m━━━━━━━━━━━━━━━━━━━━━━━ 14/34 [multidict]
#   Attempting uninstall: torch━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 28/34 [aiohttp]usolver-cu12]
#     Found existing installation: torch 2.5.1━━━━━╸━━━━━━━ 28/34 [aiohttp]
#     Uninstalling torch-2.5.1:━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 28/34 [aiohttp]
#       Successfully uninstalled torch-2.5.1━━━━━━━━━━━━━╺━━━━━ 29/34 [torch]http]
#   Attempting uninstall: torchvision━━━━━━━━━━━━━━━━━━━━╺━━━━━ 29/34 [torch]
#     Found existing installation: torchvision 0.20.1╺━━━━━ 29/34 [torch]
#     Uninstalling torchvision-0.20.1:━━━━━━━━━━━━━━━━━━━━╺━━━━ 30/34 [torchvision]
#       Successfully uninstalled torchvision-0.20.1━━━━━━━╺━━━━ 30/34 [torchvision]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [evaluate]5;237m━ 33/34 [evaluate]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 async-timeout-5.0.1 attrs-25.3.0 datasets-4.0.0 dill-0.3.8 evaluate-0.4.5 frozenlist-1.7.0 fsspec-2025.3.0 multidict-6.6.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 propcache-0.3.2 pyarrow-21.0.0 timm-1.0.19 torch-2.7.1 torchvision-0.22.1 triton-3.3.1 xxhash-3.5.0 yarl-1.20.1

# %%
model = timm.create_model(
    "deit_base_patch16_224",
    pretrained=True,
    num_classes=NUM_CLASSES
)
model = model.to(DEVICE)

# Mixed-precision amp (faster on GPUs that support it)
scaler = GradScaler()

# ------------------------------------------------------------------------
# 5.  Loss, optimiser, scheduler
# ------------------------------------------------------------------------
criterion  = nn.CrossEntropyLoss()
optimizer  = optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler  = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# ------------------------------------------------------------------------
# 6.  Train / eval loops
# ------------------------------------------------------------------------
def run_epoch(loader, train=True):
    model.train(train)
    epoch_loss, correct, total = 0.0, 0, 0

    for imgs, labels in tqdm(loader, leave=False):
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)

        with torch.set_grad_enabled(train), autocast():
            outputs = model(imgs)
            loss    = criterion(outputs, labels)

        if train:
            optimizer.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        epoch_loss += loss.item() * imgs.size(0)
        preds       = outputs.argmax(dim=1)
        correct    += (preds == labels).sum().item()
        total      += labels.size(0)

    return epoch_loss / total, correct / total


# ------------------------------------------------------------------------
# 7.  Main training loop
# ------------------------------------------------------------------------
best_wts, best_acc = copy.deepcopy(model.state_dict()), 0.0

for epoch in range(1, EPOCHS + 1):
    t0 = time.time()

    train_loss, train_acc = run_epoch(train_loader, train=True)
    val_loss,   val_acc   = run_epoch(val_loader,   train=False)
    scheduler.step()

    if val_acc > best_acc:
        best_acc, best_wts = val_acc, copy.deepcopy(model.state_dict())

    print(f"Epoch {epoch:02}/{EPOCHS} │ "
          f"train {train_loss:.3f} / {train_acc:.1%} │ "
          f"val {val_loss:.3f} / {val_acc:.1%} │ "
          f"{time.time()-t0:.1f}s")

# ------------------------------------------------------------------------
# 8.  Save best checkpoint
# ------------------------------------------------------------------------
model.load_state_dict(best_wts)
torch.save(model.state_dict(), "deit_base_patch16_retina.pth")
print(f"🎉 Best validation accuracy: {best_acc:.2%}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = timm.create_model(
#       2     "deit_base_patch16_224",
#       3     pretrained=True,
#       4     num_classes=NUM_CLASSES
#       5 )
#       6 model = model.to(DEVICE)
#       8 # Mixed-precision amp (faster on GPUs that support it)
#
# NameError: name 'timm' is not defined
